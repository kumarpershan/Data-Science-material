# %%
col = ['red', 'green', 'yellow']
fruits = ['apple', 'grapes', 'banana', 'orange']
for i in col: # green
    for j in fruits: # apple
        print(i, j)

print('Hello')
# Out:
# red apple
# red grapes
# red banana
# red orange
# green apple
# green grapes
# green banana
# green orange
# yellow apple
# yellow grapes
# yellow banana
# yellow orange
# Hello

# %%
if 2>3:
    pass
    
print('Hello')
# Out:
# Hello

# %% [markdown]
# # While Loop

# %%
i = 1
while i<6:
    print(i)
    i +=1
print('Python')
# Out:
# 1
# 2
# 3
# 4
# 5
# Python

# %%
i = 1
while i<6:
    i +=1
    break
    print(i)
   
print('Python')
# Out:
# Python

# %%
for i in range(3,19):
    if i%6==0:
        break
    print(i)
# Out:
# 3
# 4
# 5

# %%
username = 'python'
password = 1234
while 1:
    user = input('Enter Username:')
    passw = int(input('Enter password: '))
    if user == username and passw == password:
        print('Login Sucessfully')
        break
    else:
        print('Invalid ')
# Out:
# Enter Username: python
# Enter password:  1234
# Login Sucessfully

# %%
count= 0

while count<3:
    count = count+1
    user = input('Enter Username:')
    passw = int(input('Enter password: '))
    if user == username and pasw == password:
        print('Login Sucessfully')
        break
    else:
        print(count)                   
        print('Invalid ')
if count==3:
    print('Cant try more than 3')
# Out:
# Enter Username: dc
# Enter password:  13
# 1
# Invalid
# Enter Username: nnkl
# Enter password:  23
# 2
# Invalid
# Enter Username: kjbl
# Enter password:  42
# 3
# Invalid
# Cant try more than 3

# %%
count= 0
username = 'python'
password = 1234
while count>0:
    user = input('Enter Username:')
    passw = int(input('Enter password: '))
    if user == username and pasw == password:
        print('Login Sucessfully')
        break
    else:
        count -=1
        if count>0:
            print('wromg user and password', count)
        else:
            print('All three attempts filled!')
# Out:
# Enter Username: phf
# Enter password:  234
# wromg user and password 2
# Enter Username: bflf
# Enter password:  242
# wromg user and password 1
# Enter Username: bfd
# Enter password:  23
# All three attempts filled!

# %%
i = 0
while i<6:
    i +=1
    if i==3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
for i in range(10):
    if i%2==0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
num = int(input('Enter a number: '))
for i in range(1,11):
    print(f'{num} x {i} = {num*i}')
# Out:
# Enter a number:  19
# 19 x 1 = 19
# 19 x 2 = 38
# 19 x 3 = 57
# 19 x 4 = 76
# 19 x 5 = 95
# 19 x 6 = 114
# 19 x 7 = 133
# 19 x 8 = 152
# 19 x 9 = 171
# 19 x 10 = 190

# %%
for i in range(5):
    for j in range(5):
        
    print('*'*i)
# Out:
# *
# **
# ***
# ****

# %%
L = ['apple', 'mango', 'banana', '1', '2','3']
l1 = [5,6,7]

print(L+l1)
# Out:
# ['apple', 'mango', 'banana', '1', '2', '3', 5, 6, 7]

# %%
L[3]
# Out:
# '1'

# %%
L[2:5]
# Out:
# ['banana', '1', '2']

# %%
L[-4]
# Out:
# 'banana'

# %%
L[-4:-1]
# Out:
# ['banana', '1', '2']

# %%
L[-4:-7:-1]
# Out:
# ['banana', 'mango', 'apple']

# %%
'orange' in L
# Out:
# False

# %%
'mango' in L
# Out:
# True
