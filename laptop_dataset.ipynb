# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Admin\\Downloads\\laptop_pricing_dataset_base.csv")
df.head(2)
# Out:
#    Acer  4 IPS Panel  2  1  5   35.56  1.6  8  256 1.6.1  978
# 0  Dell  3   Full HD  1  1  3  39.624  2.0  4  256   2.2  634
# 1  Dell  3   Full HD  1  1  7  39.624  2.7  8  256   2.2  946

# %%
df.columns
# Out:
# Index(['Acer', '4', 'IPS Panel', '2', '1', '5', '35.56', '1.6', '8', '256',
#        '1.6.1', '978'],
#       dtype='object')

# %%
df.shape
# Out:
# (237, 12)

# %%
df.rename(columns = {'Acer': 'manufactur',
                    '4':'GPU', 
                    'IPS Panel':'screen',
                    '2':'GPU', '1': 'OS',
                    '5':'CPU_core',
                    '35.56':'Screen_Size_cm',
                    '1.6':'CPU_frequency',
                    '8':'RAM_GB',
                    '256':'Storage_GB_SSD',
                    '1.6.1':'Weight_pounds',
                    '978':'Price'}, inplace=True)

# %%
df.head(2)
# Out:
#   manufactur  GPU   screen  GPU  OS  CPU_core Screen_Size_cm  CPU_frequency  \
# 0       Dell    3  Full HD    1   1         3         39.624            2.0
# 1       Dell    3  Full HD    1   1         7         39.624            2.7
#
#    RAM_GB  Storage_GB_SSD Weight_pounds  Price
# 0       4             256           2.2    634
# 1       8             256           2.2    946

# %%
df.iloc[1,3]
# Out:
# 1

# %%
df.drop('GPU', axis=1, inplace=True)

# %%
df.head(3)
# Out:
#   manufactur     screen  OS  CPU_core Screen_Size_cm  CPU_frequency  RAM_GB  \
# 0       Dell    Full HD   1         3         39.624            2.0       4
# 1       Dell    Full HD   1         7         39.624            2.7       8
# 2       Dell  IPS Panel   1         5         33.782            1.6       8
#
#    Storage_GB_SSD Weight_pounds  Price
# 0             256           2.2    634
# 1             256           2.2    946
# 2             128          1.22   1244

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   manufactur      237 non-null    object
#  1   screen          237 non-null    object
#  2   OS              237 non-null    int64
#  3   CPU_core        237 non-null    int64
#  4   Screen_Size_cm  237 non-null    object
#  5   CPU_frequency   237 non-null    float64
#  6   RAM_GB          237 non-null    int64
#  7   Storage_GB_SSD  237 non-null    int64
#  8   Weight_pounds   237 non-null    object
#  9   Price           237 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 18.6+ KB

# %%
df.describe()
# Out:
#                OS    CPU_core  CPU_frequency      RAM_GB  Storage_GB_SSD  \
# count  237.000000  237.000000     237.000000  237.000000      237.000000
# mean     1.059072    5.632911       2.363291    7.881857      245.738397
# std      0.236258    1.243736       0.409271    2.487845       34.832516
# min      1.000000    3.000000       1.200000    4.000000      128.000000
# 25%      1.000000    5.000000       2.000000    8.000000      256.000000
# 50%      1.000000    5.000000       2.500000    8.000000      256.000000
# 75%      1.000000    7.000000       2.700000    8.000000      256.000000
# max      2.000000    7.000000       2.900000   16.000000      256.000000
#
#              Price
# count   237.000000
# mean   1464.388186
# std     574.956374
# min     527.000000
# 25%    1068.000000
# 50%    1333.000000
# 75%    1777.000000
# max    3810.000000

# %%
df['manufactur'].unique()
# Out:
# array(['Dell', 'HP', 'Acer', 'Asus', 'Lenovo', 'Huawei', 'Toshiba', 'MSI',
#        'Razer', 'Samsung', 'Xiaomi'], dtype=object)

# %%
df['OS'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df['manufactur'].value_counts()
# Out:
# manufactur
# Dell       71
# Lenovo     52
# HP         49
# Acer       18
# Asus       18
# Toshiba    17
# Samsung     5
# MSI         4
# Huawei      1
# Razer       1
# Xiaomi      1
# Name: count, dtype: int64

# %%
df['screen'].unique()
# Out:
# array(['Full HD', 'IPS Panel'], dtype=object)

# %%
df['screen'].value_counts()
# Out:
# screen
# Full HD      161
# IPS Panel     76
# Name: count, dtype: int64

# %%
df['CPU_core'].unique()
# Out:
# array([3, 7, 5], dtype=int64)

# %%
df.groupby('manufactur')['screen'].unique()
# Out:
# manufactur
# Acer       [IPS Panel, Full HD]
# Asus       [Full HD, IPS Panel]
# Dell       [Full HD, IPS Panel]
# HP         [Full HD, IPS Panel]
# Huawei              [IPS Panel]
# Lenovo     [IPS Panel, Full HD]
# MSI                   [Full HD]
# Razer                 [Full HD]
# Samsung               [Full HD]
# Toshiba    [Full HD, IPS Panel]
# Xiaomi              [IPS Panel]
# Name: screen, dtype: object

# %%
df.groupby('manufactur')['screen'].value_counts()
# Out:
# manufactur  screen
# Acer        IPS Panel    13
#             Full HD       5
# Asus        Full HD      16
#             IPS Panel     2
# Dell        Full HD      62
#             IPS Panel     9
# HP          Full HD      41
#             IPS Panel     8
# Huawei      IPS Panel     1
# Lenovo      IPS Panel    32
#             Full HD      20
# MSI         Full HD       4
# Razer       Full HD       1
# Samsung     Full HD       5
# Toshiba     IPS Panel    10
#             Full HD       7
# Xiaomi      IPS Panel     1
# Name: count, dtype: int64

# %%
df[((df['Price']< 600) | (df['Price']==600)) ]
# Out:
#    manufactur   screen  OS  CPU_core Screen_Size_cm  CPU_frequency  RAM_GB  \
# 10         HP  Full HD   1         3         39.624            2.0       4
# 11       Asus  Full HD   2         3         39.624            2.0       4
#
#     Storage_GB_SSD Weight_pounds  Price
# 10             128          1.91    558
# 11             256             2    527

# %%
df[((df['manufactur']=='Dell') & (df['CPU_core']==7) )].head(3)
# Out:
#    manufactur     screen  OS  CPU_core Screen_Size_cm  CPU_frequency  RAM_GB  \
# 1        Dell    Full HD   1         7         39.624            2.7       8
# 9        Dell    Full HD   1         7         39.624            1.8       8
# 15       Dell  IPS Panel   1         7          33.02            1.8       8
#
#     Storage_GB_SSD Weight_pounds  Price
# 1              256           2.2    946
# 9              256          2.13    975
# 15             256           1.4   1213

# %%
df.groupby('manufactur')['Price'].agg(['min', 'max', 'mean'])
# Out:
#              min   max         mean
# manufactur
# Acer         727  1650  1072.111111
# Asus         527  3810  1327.111111
# Dell         616  3665  1495.084507
# HP           558  3073  1399.285714
# Huawei      1714  1714  1714.000000
# Lenovo       634  3810  1493.096154
# MSI         1268  1714  1452.750000
# Razer       3301  3301  3301.000000
# Samsung     1904  2349  2107.400000
# Toshiba     1198  2509  1703.882353
# Xiaomi      1188  1188  1188.000000

# %%
df.groupby('screen')['Screen_Size_cm'].agg(['min', 'max'])
# Out:
#              min    max
# screen
# Full HD    31.75      ?
# IPS Panel  30.48  43.18

# %%
df[df['Screen_Size_cm'] == '?']
# Out:
#     manufactur   screen  OS  CPU_core Screen_Size_cm  CPU_frequency  RAM_GB  \
# 119       Dell  Full HD   1         5              ?            1.6       8
# 150       Dell  Full HD   1         7              ?            2.8       8
# 186    Samsung  Full HD   1         7              ?            2.7       8
# 229       Dell  Full HD   1         5              ?            2.5       8
#
#      Storage_GB_SSD Weight_pounds  Price
# 119             256          1.42   2340
# 150             256          2.06   2240
# 186             256          1.31   2031
# 229             256          1.36   1870

# %%
df[(df['manufactur']=='Dell')  & (df['screen']=='Full HD')].head(1)
# Out:
#   manufactur   screen  OS  CPU_core Screen_Size_cm  CPU_frequency  RAM_GB  \
# 0       Dell  Full HD   1         3         39.624            2.0       4
#
#    Storage_GB_SSD Weight_pounds  Price
# 0             256           2.2    634

# %%
df[(df['manufactur']=='Samsung')  & (df['screen']=='Full HD')].head(1)
# Out:
#     manufactur   screen  OS  CPU_core Screen_Size_cm  CPU_frequency  RAM_GB  \
# 181    Samsung  Full HD   1         7         33.782            2.7      16
#
#      Storage_GB_SSD Weight_pounds  Price
# 181             256          0.81   2095

# %%
df.loc[(df['manufactur'] == 'Dell') & (df['Screen_Size_cm'] == '?'),
       'Screen_Size_cm'] = 39.624

df.loc[(df['manufactur'] == 'Samsung') & (df['Screen_Size_cm'] == '?'),
       'Screen_Size_cm'] = 33.782

# %%
df[df['Screen_Size_cm'] == '?']
# Out:
# Empty DataFrame
# Columns: [manufactur, screen, OS, CPU_core, Screen_Size_cm, CPU_frequency, RAM_GB, Storage_GB_SSD, Weight_pounds, Price]
# Index: []

# %%
# Out:
# manufactur        0
# screen            0
# OS                0
# CPU_core          0
# Screen_Size_cm    0
# CPU_frequency     0
# RAM_GB            0
# Storage_GB_SSD    0
# Weight_pounds     0
# Price             0
# dtype: int64

# %%
df.groupby('manufactur')['screen'].value_counts()
# Out:
# manufactur  screen
# Acer        IPS Panel    13
#             Full HD       5
# Asus        Full HD      16
#             IPS Panel     2
# Dell        Full HD      62
#             IPS Panel     9
# HP          Full HD      41
#             IPS Panel     8
# Huawei      IPS Panel     1
# Lenovo      IPS Panel    32
#             Full HD      20
# MSI         Full HD       4
# Razer       Full HD       1
# Samsung     Full HD       5
# Toshiba     IPS Panel    10
#             Full HD       7
# Xiaomi      IPS Panel     1
# Name: count, dtype: int64
