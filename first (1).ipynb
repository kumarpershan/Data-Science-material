# %%
print('Hello')
# Out:
# Hello

# %%
name = 'Waseela'
age = 23

# %%
print(name,)
# Out:
# Waseela

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(3.125)
# Out:
# float

# %%
type('hello')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
print('hello\'s')
# Out:
# hello's

# %%
print('hello\\world')
print('hello\nWorld')
# Out:
# hello\world
# hello
# World

# %%
print('hello\tWorld')
print('hello\bWorld')
# Out:
# hello	World
# hellWorld

# %%
print('\\"\\n \\t \\\'')
# Out:
# \"\n \t \'

# %%
age1 = 23

# %%
age_1 = 23

# %%
a = '''I love Pakistan'''

# %%
a
# Out:
# 'I love Pakistan'

# %%
h = """Python, Developer"""
h
# Out:
# 'Python, Developer'

# %%
h
# Out:
# 'Python\nDeveloper'

# %%
len(h)
# Out:
# 17

# %%
len('Waseela ')
# Out:
# 8

# %%
print('a' in name)
# Out:
# True

# %%
print('z' in name)
# Out:
# False

# %% [markdown]
# # Arithmetic Operations:

# %%
print('Addition ', 2+3)
print(4-2)
print(7/3)
print(7//3)
print(2*3)
print(5**2)
print(5%2)
# Out:
# Addition  5
# 2
# 2.3333333333333335
# 2
# 6
# 25
# 1

# %%
print('My name is ', name + ' I am ', age, 'years old')
# Out:
# My name is  Waseela I am  23 years old

# %%
name1 = input('Enter your name: ')
age = int(input('Enter your age: '))
print('My name is ', name1 + ' I am ', age, 'years old')
# Out:
# Enter your name:  ali
# Enter your age:  12
# My name is  ali I am  12 years old

# %%
print(f'My name is {name1}. I am {age} years old')
# Out:
# My name is ali. I am 12 years old

# %%
num1 = int(input('Enter a number: '))
num2 = int(input('Enter a number: '))
num3 = int(input('Enter a number: '))
avg = (num1+num2+num3)/3
print(f'The average of {num1}, {num2} and {num3} is {avg}')
# Out:
# Enter a number:  2
# Enter a number:  3
# Enter a number:  4
# The average of 2, 3 and 4 is 3.0

# %% [markdown]
# # Comparision Operators

# %%
x = 10
y = 12
z = 5
print('x == y', x==y)
print('x != y', x!=y)
print('x > y', x>y)
print('x < y', x<y)
print('x >= y', x>=y)
print('x <= y', x<=y)
# Out:
# x == y False
# x != y True
# x > y False
# x < y True
# x >= y False
# x <= y True

# %%
x = 10
y = 12
z = 5
print(x>z and y>z)
# Out:
# True

# %%
print(x>z and x>y)
# Out:
# False

# %%
print(x>z or x>y)
# Out:
# True
