# %% [markdown]
# #

# %%
import numpy as np

# %%
x = np.array([2,1,4,3,5])
x
# Out:
# array([2, 1, 4, 3, 5])

# %% [markdown]
# To return a sorted version of the array without modifying the input, you can use np.sort(array)

# %%
np.sort(x)
# Out:
# array([1, 2, 3, 4, 5])

# %%
x
# Out:
# array([2, 1, 4, 3, 5])

# %%
x.sort()

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
a= np.random.randint(0, 10, (4, 6))
a
# Out:
# array([[3, 2, 4, 1, 8, 4],
#        [5, 4, 4, 9, 1, 7],
#        [1, 7, 2, 9, 4, 8],
#        [5, 4, 3, 5, 5, 8]])

# %%
np.sort(a, axis=0)
# Out:
# array([[1, 1, 0, 0, 0, 1],
#        [2, 6, 0, 5, 2, 2],
#        [4, 7, 8, 7, 6, 8],
#        [5, 8, 9, 7, 9, 9]])

# %%
np.sort(a, axis=1)
# Out:
# array([[0, 0, 5, 7, 7, 8],
#        [1, 1, 2, 2, 5, 8],
#        [0, 0, 1, 2, 6, 8],
#        [4, 6, 7, 9, 9, 9]])

# %%
np.sort(a)
# Out:
# array([[0, 0, 5, 7, 7, 8],
#        [1, 1, 2, 2, 5, 8],
#        [0, 0, 1, 2, 6, 8],
#        [4, 6, 7, 9, 9, 9]])

# %%
a.sort()
a
# Out:
# array([[0, 0, 5, 7, 7, 8],
#        [1, 1, 2, 2, 5, 8],
#        [0, 0, 1, 2, 6, 8],
#        [4, 6, 7, 9, 9, 9]])

# %%
a
# Out:
# array([[3, 2, 4, 1, 8, 4],
#        [5, 4, 4, 9, 1, 7],
#        [1, 7, 2, 9, 4, 8],
#        [5, 4, 3, 5, 5, 8]])

# %%
np.partition(a, 5)
# Out:
# array([[1, 3, 2, 4, 4, 8],
#        [1, 4, 4, 5, 7, 9],
#        [1, 2, 4, 7, 8, 9],
#        [5, 3, 4, 5, 5, 8]])

# %%
np.partition(a, 4, axis=1)
# Out:
# array([[1, 3, 2, 4, 4, 8],
#        [1, 4, 4, 5, 7, 9],
#        [1, 2, 4, 7, 8, 9],
#        [5, 3, 4, 5, 5, 8]])

# %%
a.shape
# Out:
# (4, 6)
