# %%
import pandas as pd

# %% [markdown]
# # Series
# Series(data, index), index is default parameter

# %%
s = pd.Series([2,1,3,4,5])
s
# Out:
# 0    2
# 1    1
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.values
# Out:
# array([2, 1, 3, 4, 5], dtype=int64)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s[2]
# Out:
# 3

# %%
s1 = pd.Series([0.25, 0.5, 0.75, 1],
              index = ['a', 'b', 'c', 'd'])
s1
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
s1['c']
# Out:
# 0.75

# %%
data= {
    'California': 38332521,
    'Texas': 26448193,
    'New York': 19651127,
    'Florida': 19552860,
    'Illinois': 12882135
}
s2 = pd.Series(data)
s2
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64
