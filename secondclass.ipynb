# %% [markdown]
# # String Indexing and Slicing

# %%
lang = 'Python Programming'
print(lang)
# Out:
# Python Programming

# %%
lang[2] # pgmn
# Out:
# 't'

# %%
lang[4]
# Out:
# 'o'

# %%
lang[-1]
# Out:
# 'g'

# %%
lang[6:10]
# Out:
# ' Pro'

# %%
lang[7:10]
# Out:
# 'Prog'

# %%
lang[-11:-8]
# Out:
# 'Pro'

# %%
lang[16:3:-3]
# Out:
# 'nmgPo'

# %%
lang[-2:-17:-3]
# Out:
# 'nmgPo'

# %%
lang[::-4] #mgphp gmony
# Out:
# 'gmony'

# %%
mg ny

# %%
name = input('Enter your name: ')
print(name[::-1])
# Out:
# Enter your name:  ali
# ila

# %% [markdown]
# # Strig Method

# %%
a = '  Hello World python'
a
# Out:
# '  Hello World python'

# %%
print(a.upper())
# Out:
# HELLO WORLD PYTHON

# %%
print(a.lower())
# Out:
# hello world python

# %%
print(a.strip())
# Out:
# Hello World python

# %%
print(a.replace('H', 'j'))
# Out:
#   jello World python

# %%
print(a.count('o'))
# Out:
# 3

# %%
print(a.split(' '))
# Out:
# ['', '', 'Hello', 'World', 'python']

# %%
print(a.title())
# Out:
#   Hello World Python

# %%
a.capitalize()
# Out:
# '  hello world python'

# %%
name, char = input('Enter name and any latter of your name with comma: ').split(',')
# Out:
# Enter name and any latter of your name with comma:  python development,e

# %%
print(f'The length of {name} is {len(name)}')
print(f'{char} in {name} occur {name.count(char)}times')
# Out:
# The length of python development is 18
# e in python development occur 3times

# %%
char
# Out:
# 'a'

# %%
3!=5
# Out:
# True

# %%
3!=3
# Out:
# False
