# %%
L = list(map(lambda x: x, range(1,10)))
L
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
L1 = list(map(lambda x: x**2, range(1,10)))
L1
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# # Tuple

# %%
T1 = (101, 'peter', 22)
T2 = ('apple', 'banana', 'orange')
T3 = 1,2,3,4,5

# %%
print(type(T1))
# Out:
# <class 'tuple'>

# %%
T1[0]
# Out:
# 101

# %%
T2[1]
# Out:
# 'banana'

# %%
T3[3]
# Out:
# 4

# %%
T4 = T1 + T2
T4
# Out:
# (101, 'peter', 22, 'apple', 'banana', 'orange')

# %%
T4.count(22)
# Out:
# 1

# %%
T4.index(22)
# Out:
# 2

# %%
L = list(T4)
L
# Out:
# [101, 'peter', 22, 'apple', 'banana', 'orange']

# %%
L.pop(0)
# Out:
# 101

# %%
L.insert(0,10)
L
# Out:
# [10, 'peter', 22, 'apple', 'banana', 'orange']

# %%
L.remove('orange')

# %%
L
# Out:
# [10, 'peter', 22, 'apple', 'banana']

# %%
L.append('mango')
L
# Out:
# [10, 'peter', 22, 'apple', 'banana', 'mango']

# %%
T4 = tuple(L)
T4
# Out:
# (10, 'peter', 22, 'apple', 'banana', 'mango')

# %% [markdown]
# ## Sets

# %%
s = {'apple', 'banana', 'cherry'}
s1 = {'google', 'Ms', 'apple'}
print(s)
print(s1)
# Out:
# {'banana', 'apple', 'cherry'}
# {'google', 'Ms', 'apple'}

# %%
s.add('orange')
s
# Out:
# {'apple', 'banana', 'cherry', 'orange'}

# %%
s.update(s1)
s
# Out:
# {'Ms', 'apple', 'banana', 'cherry', 'google', 'orange'}

# %%
z = s.difference(s1)
z
# Out:
# {'banana', 'cherry', 'orange'}

# %%
z = s.union(s1)
z
# Out:
# {'Ms', 'apple', 'banana', 'cherry', 'google', 'orange'}

# %%
s.remove('banana')
s
# Out:
# {'Ms', 'apple', 'cherry', 'google', 'orange'}

# %%
s.remove('mango')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 s.remove('mango')
#
# KeyError: 'mango'

# %%
s.discard('mango')

# %%
s
# Out:
# {'Ms', 'apple', 'cherry', 'google', 'orange'}

# %%
s.pop()
# Out:
# 'Ms'

# %%
z = s.intersection(s1)
z
# Out:
# {'apple', 'google'}

# %%
student = {
    'name' : 'Ali', 
    'age': 22,
    'id' : 101,
    'subejct' : 'Data Science',
    'marks' : 89,
    'batch' :5
}
student
# Out:
# {'name': 'Ali',
#  'age': 22,
#  'id': 101,
#  'subejct': 'Data Science',
#  'marks': 89,
#  'batch': 5}

# %%
type(student)
# Out:
# dict

# %%
student['age']
# Out:
# 22

# %%
student.get('age')
# Out:
# 22

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'id', 'subejct', 'marks', 'batch'])

# %%
student.values()
# Out:
# dict_values(['Ali', 22, 101, 'Data Science', 89, 5])

# %%
student.items()
# Out:
# dict_items([('name', 'Ali'), ('age', 22), ('id', 101), ('subejct', 'Data Science'), ('marks', 89), ('batch', 5)])

# %%
'id' in student
# Out:
# True

# %%
student['lname'] = 'Khan'
student
# Out:
# {'name': 'Ali',
#  'age': 22,
#  'id': 101,
#  'subejct': 'Data Science',
#  'marks': 89,
#  'batch': 5,
#  'lname': 'Khan'}

# %%
student['marks'] = 98
student
# Out:
# {'name': 'Ali',
#  'age': 22,
#  'id': 101,
#  'subejct': 'Data Science',
#  'marks': 98,
#  'batch': 5,
#  'lname': 'Khan'}

# %%
student.update({'fname':'rehman'})
student
# Out:
# {'name': 'Ali',
#  'age': 22,
#  'id': 101,
#  'subejct': 'Data Science',
#  'marks': 98,
#  'batch': 5,
#  'lname': 'Khan',
#  'fname': 'rehman'}

# %%
student.update({'id' : 200})
student
# Out:
# {'name': 'Ali',
#  'age': 22,
#  'id': 200,
#  'subejct': 'Data Science',
#  'marks': 98,
#  'batch': 5,
#  'lname': 'Khan',
#  'fname': 'rehman'}

# %%
student.pop('fname')
student
# Out:
# {'name': 'Ali',
#  'age': 22,
#  'id': 200,
#  'subejct': 'Data Science',
#  'marks': 98,
#  'batch': 5,
#  'lname': 'Khan'}

# %%
student.popitem()
student
# Out:
# {'name': 'Ali',
#  'age': 22,
#  'id': 200,
#  'subejct': 'Data Science',
#  'marks': 98,
#  'batch': 5}
