# %% [markdown]
# # Conditional Statements

# %%
a = 23
b = 34
if b>a:
    print('a is greater than b')
# Out:
# a is greater than b

# %%
if b<a:
    print('a is greater than b')
else:
    print('a is less than b')
# Out:
# a is less than b

# %%
a = 23
b = 34
if a>b:
    print('a is geater than b')
elif a<b:
    print('a is less than b')
elif a==b:
    print('a is equal to b')
# Out:
# a is less than b

# %%
num = int(input('Enter a number: '))
num1 = int(input('Enter a number: '))
if num>num1:
    print(f'{num} is greater than {num1}')
elif num1>num:
    print(f'{num1} is greater than {num}')
elif num1==num:
    print(f'{num1} is equal to {num}')
# Out:
# Enter a number:  3
# Enter a number:  3
# 3 is equal to 3

# %%
num = int(input('Enter a num: '))
if num % 2==0:
    print('Even')
else:
    print('Odd')
# Out:
# Enter a num:  57
# Odd

# %%
num =  int(input('Enter a number: '))
if num%3==0 and num%5==0:
    print('Divisible by 3 and 5')
elif num%5==0:
    print('Divisible by 5')
elif num%3==0 :
    print('Divisible by 3 ')
else:
    print('Not divisile ')
# Out:
# Enter a number:  26
# Not divisile

# %%
username = 'python'
password = '1234'
user = input('Enter your user name: ')
passw = input('Enter your password: ')
if user==username and passw==password:
    print('Login Sucessfully')
else:
    print('Invalid Username or password')
# Out:
# Enter your user name:  vufi
# Enter your password:  1234
# Invalid Username or password

# %%
user = input('Enter your user name: ')
passw = input('Enter your password: ')
if user!=username and passw!=password:
    print('Invalid Username and password')
    
elif user!=username:
    print('Username is incorrect')
elif passw != password:
    print('Invalid Password')
else:
    print('Login Sucessfully')
# Out:
# Enter your user name:  fyujfi
# Enter your password:  1465
# Invalid Username and password

# %%
a = int(input('Enter an number: '))
b = int(input('Enter an number: '))
c = int(input('Enter an number: '))

if a>b and a>c:
    print(f'{a} is greater')
elif b>a and b>c:
    print(f'{b} is greater')
elif c>a and c>b:
    print(f'{c} is greater')

if a<b and a<c:
    print(f'{a} is smallest')
elif b<c and b<a:
    print(f'{b} is smallest')
else:
    print(f'{c} is smallest')

# %%
vow = 'aeiouAEIOU'
a = input('Enter character')
if a in vow:
    print('Vowel')
else:
    print('Consonant')
# Out:
# Enter character A
# Vowel

# %%
vow = 'aeiou'
a = input('Enter character')
if a.lower() in vow:
    print('Vowel')
else:
    print('Consonant')
# Out:
# Enter character E
# Vowel
